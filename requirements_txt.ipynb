# %% [markdown]
# <a href="https://colab.research.google.com/github/dani3lkim/Poke/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
streamlit
pandas
matplotlib
requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2653476189.py in <cell line: 0>()
# ----> 1 streamlit
#       2 pandas
#       3 matplotlib
#       4 requests
#
# NameError: name 'streamlit' is not defined
